# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# %pip install --upgrade jupyter
# %pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: jupyter in d:\anaconda\envs\mchatbot\lib\site-packages (1.0.0)
# Requirement already satisfied: notebook in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter) (7.2.0)
# Requirement already satisfied: qtconsole in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter) (6.29.3)
# Requirement already satisfied: ipywidgets in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter) (8.1.3)
# Requirement already satisfied: comm>=0.1.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets->jupyter) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-console->jupyter) (3.0.42)
# Requirement already satisfied: pygments in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-console->jupyter) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from notebook->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from notebook->jupyter) (2.27.2)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from notebook->jupyter) (4.2.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in d:\anaconda\envs\mchatbot\lib\site-packages (from notebook->jupyter) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda\envs\mchatbot\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: decorator in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: stack-data in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.6 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.11.0)
# Requirement already satisfied: colorama in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.2.2)
# Requirement already satisfied: pywin32>=300 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.4.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.20.0)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2.2.5)
# Requirement already satisfied: babel>=2.10 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.15.0)
# Requirement already satisfied: json5>=0.9.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (4.22.0)
# Requirement already satisfied: requests>=2.31 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\anaconda\envs\mchatbot\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.19.1)
# Requirement already satisfied: wcwidth in d:\anaconda\envs\mchatbot\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\envs\mchatbot\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\envs\mchatbot\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.7)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\anaconda\envs\mchatbot\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: certifi in d:\anaconda\envs\mchatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\envs\mchatbot\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\anaconda\envs\mchatbot\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (0.18.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\mchatbot\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook->jupyter) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in d:\anaconda\envs\mchatbot\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in d:\anaconda\envs\mchatbot\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in d:\anaconda\envs\mchatbot\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\anaconda\envs\mchatbot\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.9.0.20240316)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in d:\anaconda\envs\mchatbot\lib\site-packages (8.1.3)
# Requirement already satisfied: comm>=0.1.3 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets) (8.25.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: decorator in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: typing-extensions>=4.6 in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: colorama in d:\anaconda\envs\mchatbot\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\anaconda\envs\mchatbot\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in d:\anaconda\envs\mchatbot\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in d:\anaconda\envs\mchatbot\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\envs\mchatbot\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from langchain.embeddings import HuggingFaceEmbeddings
# from langchain.vectorstores import Pinecone
import pinecone
# from langchain.embeddings import Embeddings
from langchain.vectorstores import Pinecone as LangchainPinecone
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain.llms import CTransformers

# %%
# PINECONE_API_KEY = "5851aa9a-ea47-4c66-a323-bdbfeed95371"
import os
from dotenv import load_dotenv
PINECONE_API_KEY = os.getenv('PINECONE_API_KEY')
os.environ['PINECONE_API_KEY'] = PINECONE_API_KEY

# %%
def load_pdf(data):
    loader = DirectoryLoader(data, glob="*.pdf", loader_cls=PyPDFLoader)
    document = loader.load()
    return document

# %%
import os
pdf_path = os.path.join('..', 'data')
extracted_data = load_pdf(pdf_path)

# %%
# Create text chunks
def text_split(extracted_data):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 20)
    text_chunks = text_splitter.split_documents(extracted_data)
    return text_chunks

# %%
text_chunks = text_split(extracted_data)
print("Chunk Length: ", len(text_chunks))
# Out:
# Chunk Length:  7020

# %%
# Download embedding model
def download_hugging_face_embeddings():
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    return embeddings

# %%
embeddings = download_hugging_face_embeddings()

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
query_result = embeddings.embed_query("Hello World")
print("Length", len(query_result))
# Out:
# Length 384

# %%
query_result
# Out:
# [-0.03447718918323517,
#  0.031023189425468445,
#  0.006734984926879406,
#  0.026109009981155396,
#  -0.03936197981238365,
#  -0.16030246019363403,
#  0.06692398339509964,
#  -0.006441500969231129,
#  -0.04745054990053177,
#  0.01475889328867197,
#  0.07087533175945282,
#  0.05552756413817406,
#  0.01919332891702652,
#  -0.02625131793320179,
#  -0.01010945811867714,
#  -0.026940524578094482,
#  0.022307483479380608,
#  -0.022226670756936073,
#  -0.14969268441200256,
#  -0.017493031919002533,
#  0.007676261011511087,
#  0.05435234680771828,
#  0.0032544753048568964,
#  0.03172600269317627,
#  -0.06405667960643768,
#  -0.08389385044574738,
#  0.061362411826848984,
#  -0.03354554623365402,
#  -0.10615335404872894,
#  -0.04008051007986069,
#  0.03253021091222763,
#  0.07662483304738998,
#  -0.07301614433526993,
#  0.00033757087658159435,
#  -0.04087160900235176,
#  -0.07578840851783752,
#  0.02752763219177723,
#  0.0746254175901413,
#  0.01771729439496994,
#  0.09121838957071304,
#  0.11022023856639862,
#  0.0005697952583432198,
#  0.051463350653648376,
#  -0.014551321975886822,
#  0.033232007175683975,
#  0.023792268708348274,
#  -0.02288973703980446,
#  0.03893759474158287,
#  0.030206790193915367]

# %%
from pinecone import Pinecone, ServerlessSpec
pc = Pinecone(api_key=PINECONE_API_KEY)
index_name = "medical-chatbot"

# %%
# Creating embedding for each of the text chunks and storing
# docsearch = Pinecone.from_texts([t.page_content for t in text_chunks], embeddings, index_name = index_name)
docsearch = LangchainPinecone.from_texts(
    texts=[t.page_content for t in text_chunks],
    embedding=embeddings,
    index_name=index_name,
)

# %%
docsearch = LangchainPinecone.from_existing_index(index_name, embeddings)
query = "What are allergies ?"
docs = docsearch.similarity_search(query, k = 3)
print("Result", docs)
# Out:
# Result [Document(page_content='the itchy, scratchy nose, eyes, and throat common inallergic rhinitis .\nThe particular allergens to which a person is sensi-'), Document(page_content='the itchy, scratchy nose, eyes, and throat common inallergic rhinitis .\nThe particular allergens to which a person is sensi-'), Document(page_content='the itchy, scratchy nose, eyes, and throat common inallergic rhinitis .\nThe particular allergens to which a person is sensi-')]

# %%
prompt_template="""
Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

# %%
PROMPT=PromptTemplate(template=prompt_template, input_variables=["context", "question"])
chain_type_kwargs={"prompt": PROMPT}

# %%
# from huggingface_hub import login
# login(token="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")

llm = CTransformers(model="../model/llama-2-7b-chat.ggmlv3.q4_0.bin",
                    model_type="llama",
                    config={"max_new_tokens":512,
                            'temperature':0.8})

# %%
qa=RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type="stuff", 
    retriever=docsearch.as_retriever(search_kwargs={'k': 2}),
    return_source_documents=True, 
    chain_type_kwargs=chain_type_kwargs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 qa=RetrievalQA.from_chain_type(
#       2     llm=llm,
#       3     chain_type="stuff",
#       4     retriever=docsearch.as_retriever(search_kwargs={'k': 2}),
#       5     return_source_documents=True,
#       6     chain_type_kwargs=chain_type_kwargs)
#
# NameError: name 'RetrievalQA' is not defined

# %%
while True:
    user_input=input(f"Input Prompt:")
    result=qa({"query": user_input})
    print("Response : ", result["result"])
# Out:
# Response :  The disease caused by a lack of vitamin C is known as scurvy.
# Response :  Acne is a common skin disease characterized by pimples on the face, chest, and back. It occurs when the pores of the skin become clogged with oil, dead skin cells, and bacteria.
